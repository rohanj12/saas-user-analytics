# %% [markdown]
# ## 1. DATASET PREPARATION

# %%
import pandas as pd

df = pd.read_csv('/Users/rohanjairam/projects/saas-user-analytics/data/raw_data.csv')

df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No       1           No
# 1  5575-GNVDE    Male            No      No         No      34          Yes
# 2  3668-QPYBK    Male            No      No         No       2          Yes
# 3  7795-CFOCW    Male            No      No         No      45           No
# 4  9237-HQITU  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#Structure of Data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   object
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
#Summary Statistics
df.describe(include='all')
# Out:
#         customerID gender SeniorCitizen Partner Dependents       tenure  \
# count         7032   7032          7032    7032       7032  7032.000000
# unique        7032      2             2       2          2          NaN
# top     7590-VHVEG   Male            No      No         No          NaN
# freq             1   3549          5890    3639       4933          NaN
# mean           NaN    NaN           NaN     NaN        NaN    32.421786
# std            NaN    NaN           NaN     NaN        NaN    24.545260
# min            NaN    NaN           NaN     NaN        NaN     1.000000
# 25%            NaN    NaN           NaN     NaN        NaN     9.000000
# 50%            NaN    NaN           NaN     NaN        NaN    29.000000
# 75%            NaN    NaN           NaN     NaN        NaN    55.000000
# max            NaN    NaN           NaN     NaN        NaN    72.000000
#
#        PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
#Null Count
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#Convert this column to a numeric one
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'],errors='coerce')

#Remove all null values
df.dropna(subset=['TotalCharges'], inplace=True)

#Reset the index
df.reset_index(drop=True, inplace=True)

# %%
df['SeniorCitizen'] = df['SeniorCitizen'].map({1: 'Yes', 0: 'No'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     0 non-null      object
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
df.to_csv('/Users/rohanjairam/projects/saas-user-analytics/data/raw_data.csv', index=False)

# %% [markdown]
# ## 2. EXPLORATORY DATA ANALYSIS

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")
# %matplotlib inline

# %%
df = pd.read_csv('/Users/rohanjairam/projects/saas-user-analytics/data/raw_data.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            NaN     Yes         No       1           No
# 1  5575-GNVDE    Male            NaN      No         No      34          Yes
# 2  3668-QPYBK    Male            NaN      No         No       2          Yes
# 3  7795-CFOCW    Male            NaN      No         No      45           No
# 4  9237-HQITU  Female            NaN      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (7032, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   object
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
df.describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7032.000000     7032.000000   7032.000000
# mean     32.421786       64.798208   2283.300441
# std      24.545260       30.085974   2266.771362
# min       1.000000       18.250000     18.800000
# 25%       9.000000       35.587500    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.862500   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
churn_counts = df['Churn'].value_counts()
churn_rate = df['Churn'].value_counts(normalize=True) * 100

print("Churn Rate (%):\n", churn_rate)
# Out:
# Churn Rate (%):
#  No     73.421502
# Yes    26.578498
# Name: Churn, dtype: float64

# %%
sns.countplot(x='Churn', data=df)
plt.title("Churn Distribution")
plt.show()

# %%
sns.countplot(x='Contract', hue='Churn', data=df)
plt.title("Churn by Contract Type")
plt.xlabel("Contract Type")
plt.ylabel("Number of Customers")
plt.show()

# %%
sns.histplot(data=df, x='tenure', hue='Churn', kde=True, bins=30)
plt.title("Tenure Distribution by Churn Status")
plt.xlabel("Months with Company")
# Out:
# Text(0.5, 0, 'Months with Company')

# %%
numerics = df.select_dtypes(include=['int64', 'float64'])
corr_matrix = numerics.corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.boxplot(x='Churn', y='TotalCharges', data=df)
plt.title("Total Charges by Churn Status")
# Out:
# Text(0.5, 1.0, 'Total Charges by Churn Status')

# %%
df.to_csv('../data/eda_ready.csv', index=False)

# %% [markdown]
# ## Key Observations:
# - Overall churn rate is ~27%.
# - Customers with month-to-month contracts churn significantly more.
# - Short-tenure users are at high churn risk.
# - Monthly charges and total charges are higher among those who churned.
